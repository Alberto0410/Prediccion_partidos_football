# %%
import import_ipynb
from procesamiento import *
from funciones import *
# Out:
# importing Jupyter notebook from procesamiento.ipynb
# ...
# importing Jupyter notebook from funciones.ipynb
# <string>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
modelo('2011-12','2012-13', historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ***RESULTADOS TEMPORADA 2012-13
#
# ****Porcenaje de aciertos: 49.26470588235294%
# ***Top 5 equipos con más aciertos:
#
# Para el equipo Sevilla el modelo acertó a 20 partidos de 32
# Para el equipo Valencia el modelo acertó a 19 partidos de 32
# ...

# %%
modelo('2012-13','2013-14', historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ***RESULTADOS TEMPORADA 2013-14
#
# ****Porcenaje de aciertos: 45.588235294117645%
# ***Top 5 equipos con más aciertos:
#
# Para el equipo Atletico de Bilbao el modelo acertó a 18 partidos de 32
# Para el equipo Real Sociedad el modelo acertó a 17 partidos de 32
# ...

# %%
modelo('2013-14','2014-15', historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ***RESULTADOS TEMPORADA 2014-15
#
# ****Porcenaje de aciertos: 48.89705882352941%
# ***Top 5 equipos con más aciertos:
#
# Para el equipo Sevilla el modelo acertó a 21 partidos de 32
# Para el equipo Espanol el modelo acertó a 19 partidos de 32
# ...

# %%
modelo('2014-15','2015-16', historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ***RESULTADOS TEMPORADA 2015-16
#
# ****Porcenaje de aciertos: 48.89705882352941%
# ***Top 5 equipos con más aciertos:
#
# Para el equipo Barcelona el modelo acertó a 23 partidos de 32
# Para el equipo Levante el modelo acertó a 21 partidos de 32
# ...

# %%
#cuando se le indica el cuarto parametro, el modelo muestra 
# los resultados hasta esa jornada, además de la prediccion 
# para la siguiente jornada
modelo('2015-16','2016-17', historico, 16)
# Out:
# ***RESULTADOS TEMPORADA 2016-17
#
# ****Porcenaje de aciertos: 48.89705882352941%
# ***Top 5 equipos con más aciertos:
#
# Para el equipo Atletico de Bilbao el modelo acertó a 23 partidos de 32
# Para el equipo Las Palmas el modelo acertó a 21 partidos de 32
# Para el equipo Granada el modelo acertó a 18 partidos de 32
# Para el equipo Deportivo el modelo acertó a 18 partidos de 32
# Para el equipo Sevilla el modelo acertó a 17 partidos de 32
#
# ***El porcentaje de aciertos sobre los locales es 65.19%
# ***El porcentaje de aciertos sobre los visitantes es 50.0%
# ***El porcentaje de aciertos sde empate es 20.48%
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ...

# %%
barcelona(historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only

# %%
promedios_fin(historico)
# Out:
# <string>:29: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:30: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:38: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:47: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# <string>:45: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
# ***El porcentaje de la precisión del modelo en de la temporada 2012-13 a la 2016-17 son:
# * 60.23029462420041 para los locales
# * 24.545454545454547 para las visitas
# * 24.878474047191805 para los empates
#
# ...
